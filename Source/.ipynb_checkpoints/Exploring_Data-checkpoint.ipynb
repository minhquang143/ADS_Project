# %% [markdown]
# <div style="text-align: center; background-color: #5A96E3; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Exploring Data</div>

# %% [markdown]
# <h2>Import</h2>

# %%
import numpy as np
import pandas as pd
import datetime
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.simplefilter('ignore')

# %% [markdown]
# <h2>Exploring your data</h2>

# %% [markdown]
# <h3>Read raw data from file</h3>

# %%
raw_df = pd.DataFrame()
raw_df = pd.read_csv('../Data/data_footballer.csv')

# %%
# TEST
raw_df.head()
# Out:
#                 Name  Height Weight Preferred Foot     Birth Date  Age  \
# 0    Erling Haaland   195 cm  94 kg           Left  July 21, 2000   23
# 1     Kylian Mbappé   182 cm  75 kg          Right  Dec. 20, 1998   24
# 2   Kevin De Bruyne   181 cm  75 kg          Right  June 28, 1991   32
# 3        Harry Kane   188 cm  85 kg          Right  July 28, 1993   30
# 4  Thibaut Courtois   199 cm  96 kg           Left   May 11, 1992   31
#
#     Nation                 Club                      League  \
# 0   Norway      Manchester City  England Premier League (1)
# 1   France  Paris Saint-Germain          France Ligue 1 (1)
# 2  Belgium      Manchester City  England Premier League (1)
# 3  England       Bayern München   Germany 1. Bundesliga (1)
# 4  Belgium          Real Madrid  Spain Primera Divisi처n (1)
#
#   Preferred Positions  ...  Long Shots  Curve FK Acc. Penalties  Volleys  \
# 0                  ST  ...          86     77      62        84       90
# 1              ST, LW  ...          83     80      69        84       85
# 2             CM, CAM  ...          92     92      83        83       83
# 3                  ST  ...          87     82      65        92       89
# 4                  GK  ...          17     19      20        27       12
#
#    GK Positioning GK Diving  GK Handling  GK Kicking  GK Reflexes
# 0              11         7           14          13            7
# 1              11        13            5           7            6
# 2              10        15           13           5           13
# 3              14         8           10          11           11
# 4              90        85           89          76           93
#
# [5 rows x 48 columns]

# %% [markdown]
# <h3>How many rows and how many columns does the raw data have?</h3>

# %%
rows=len(raw_df.axes[0])
cols=len(raw_df.axes[1])
shape=(rows,cols)
print(f"Current shape: {shape}")
# Out:
# Current shape: (10020, 48)

# %% [markdown]
# The league column has a misspelling in some name. We replace to correct.

# %%
raw_df['League'] = raw_df['League'].str.replace('처', 'o')
raw_df['League'] = raw_df['League'].str.replace('체', 'u')

# %% [markdown]
# <h3>What data type does each column currently have? Are there any columns whose data types are not suitable for further processing?</h3>

# %% [markdown]
# <h4>Convert all columns into their correct datatype before doing anything else</h4>

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  object
#  2   Weight               10020 non-null  object
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  object
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Club                 10020 non-null  object
#  8   League               10020 non-null  object
#  9   Preferred Positions  10020 non-null  object
#  10  OVR                  10020 non-null  int64
#  11  POT                  10020 non-null  int64
#  12  Value                10020 non-null  object
#  13  Wage                 10020 non-null  object
#  14  Ball Control         10020 non-null  int64
#  15  Dribbling            10020 non-null  int64
#  16  Marking              10020 non-null  object
#  17  Slide Tackle         10020 non-null  int64
#  18  Stand Tackle         10020 non-null  int64
#  19  Aggression           10020 non-null  int64
#  20  Reactions            10020 non-null  int64
#  21  Att. Position        10020 non-null  int64
#  22  Interceptions        10020 non-null  int64
#  23  Vision               10020 non-null  int64
#  24  Composure            10020 non-null  int64
#  25  Crossing             10020 non-null  int64
#  26  Short Pass           10020 non-null  int64
#  27  Long Pass            10020 non-null  int64
#  28  Acceleration         10020 non-null  int64
#  29  Stamina              10020 non-null  int64
#  30  Strength             10020 non-null  int64
#  31  Balance              10020 non-null  int64
#  32  Sprint Speed         10020 non-null  int64
#  33  Agility              10020 non-null  int64
#  34  Jumping              10020 non-null  int64
#  35  Heading              10020 non-null  int64
#  36  Shot Power           10020 non-null  int64
#  37  Finishing            10020 non-null  int64
#  38  Long Shots           10020 non-null  int64
#  39  Curve                10020 non-null  int64
#  40  FK Acc.              10020 non-null  int64
#  41  Penalties            10020 non-null  int64
#  42  Volleys              10020 non-null  int64
#  43  GK Positioning       10020 non-null  int64
#  44  GK Diving            10020 non-null  int64
#  45  GK Handling          10020 non-null  int64
#  46  GK Kicking           10020 non-null  int64
#  47  GK Reflexes          10020 non-null  int64
# dtypes: int64(36), object(12)
# memory usage: 3.7+ MB

# %% [markdown]
# Column `Birth Date` should be converted to datetime.

# %%
cols_change=['Value','Wage', 'Marking']
raw_df['Value'] = raw_df['Value'].str.replace('.','')
raw_df['Wage'] = raw_df['Wage'].str.replace('.','')
raw_df[cols_change] = raw_df[cols_change].apply(pd.to_numeric, errors='coerce')
raw_df['Birth Date'] = raw_df['Birth Date'].str.replace('.','').str.replace('Sept', 'Sep')
converted_dates = []
for i in range(len(raw_df['Birth Date'])):
    try:
        converted_dates.append(pd.to_datetime(raw_df['Birth Date'].iloc[i], format='%b %d, %Y'))
    except ValueError:
        converted_dates.append(pd.to_datetime(raw_df['Birth Date'].iloc[i], format='%B %d, %Y'))

raw_df['Birth Date'] = converted_dates
raw_df['Height'] = raw_df['Height'].str.rstrip(' cm').astype(int)
raw_df['Weight'] = raw_df['Weight'].str.rstrip(' kg').astype(int)

# %%
# TEST
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  int64
#  2   Weight               10020 non-null  int64
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  datetime64[ns]
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Club                 10020 non-null  object
#  8   League               10020 non-null  object
#  9   Preferred Positions  10020 non-null  object
#  10  OVR                  10020 non-null  int64
#  11  POT                  10020 non-null  int64
#  12  Value                9961 non-null   float64
#  13  Wage                 9961 non-null   float64
#  14  Ball Control         10020 non-null  int64
#  15  Dribbling            10020 non-null  int64
#  16  Marking              0 non-null      float64
#  17  Slide Tackle         10020 non-null  int64
#  18  Stand Tackle         10020 non-null  int64
#  19  Aggression           10020 non-null  int64
#  20  Reactions            10020 non-null  int64
#  21  Att. Position        10020 non-null  int64
#  22  Interceptions        10020 non-null  int64
#  23  Vision               10020 non-null  int64
#  24  Composure            10020 non-null  int64
#  25  Crossing             10020 non-null  int64
#  26  Short Pass           10020 non-null  int64
#  27  Long Pass            10020 non-null  int64
#  28  Acceleration         10020 non-null  int64
#  29  Stamina              10020 non-null  int64
#  30  Strength             10020 non-null  int64
#  31  Balance              10020 non-null  int64
#  32  Sprint Speed         10020 non-null  int64
#  33  Agility              10020 non-null  int64
#  34  Jumping              10020 non-null  int64
#  35  Heading              10020 non-null  int64
#  36  Shot Power           10020 non-null  int64
#  37  Finishing            10020 non-null  int64
#  38  Long Shots           10020 non-null  int64
#  39  Curve                10020 non-null  int64
#  40  FK Acc.              10020 non-null  int64
#  41  Penalties            10020 non-null  int64
#  42  Volleys              10020 non-null  int64
#  43  GK Positioning       10020 non-null  int64
#  44  GK Diving            10020 non-null  int64
#  45  GK Handling          10020 non-null  int64
#  46  GK Kicking           10020 non-null  int64
#  47  GK Reflexes          10020 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(38), object(6)
# memory usage: 3.7+ MB

# %% [markdown]
# <h3>Check missing value and solve missing value in data</h3>

# %%
missing_ratio=(raw_df.isnull().sum()/len(raw_df)*100).round(2)
missing_ratio
# Out:
# Name                     0.00
# Height                   0.00
# Weight                   0.00
# Preferred Foot           0.00
# Birth Date               0.00
# Age                      0.00
# Nation                   0.00
# Club                     0.00
# League                   0.00
# Preferred Positions      0.00
# OVR                      0.00
# POT                      0.00
# Value                    0.59
# Wage                     0.59
# Ball Control             0.00
# Dribbling                0.00
# Marking                100.00
# Slide Tackle             0.00
# Stand Tackle             0.00
# Aggression               0.00
# Reactions                0.00
# Att. Position            0.00
# Interceptions            0.00
# Vision                   0.00
# Composure                0.00
# Crossing                 0.00
# Short Pass               0.00
# Long Pass                0.00
# Acceleration             0.00
# Stamina                  0.00
# Strength                 0.00
# Balance                  0.00
# Sprint Speed             0.00
# Agility                  0.00
# Jumping                  0.00
# Heading                  0.00
# Shot Power               0.00
# Finishing                0.00
# Long Shots               0.00
# Curve                    0.00
# FK Acc.                  0.00
# Penalties                0.00
# Volleys                  0.00
# GK Positioning           0.00
# GK Diving                0.00
# GK Handling              0.00
# GK Kicking               0.00
# GK Reflexes              0.00
# dtype: float64

# %% [markdown]
# If the percentage of missing values is greater than 75%, the column is dropped from the dataframe.

# %%
for i in missing_ratio.keys():
    if missing_ratio[i]>75.0:
        raw_df=raw_df.drop(columns=[i])

# %%
# TEST
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 47 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  int64
#  2   Weight               10020 non-null  int64
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  datetime64[ns]
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Club                 10020 non-null  object
#  8   League               10020 non-null  object
#  9   Preferred Positions  10020 non-null  object
#  10  OVR                  10020 non-null  int64
#  11  POT                  10020 non-null  int64
#  12  Value                9961 non-null   float64
#  13  Wage                 9961 non-null   float64
#  14  Ball Control         10020 non-null  int64
#  15  Dribbling            10020 non-null  int64
#  16  Slide Tackle         10020 non-null  int64
#  17  Stand Tackle         10020 non-null  int64
#  18  Aggression           10020 non-null  int64
#  19  Reactions            10020 non-null  int64
#  20  Att. Position        10020 non-null  int64
#  21  Interceptions        10020 non-null  int64
#  22  Vision               10020 non-null  int64
#  23  Composure            10020 non-null  int64
#  24  Crossing             10020 non-null  int64
#  25  Short Pass           10020 non-null  int64
#  26  Long Pass            10020 non-null  int64
#  27  Acceleration         10020 non-null  int64
#  28  Stamina              10020 non-null  int64
#  29  Strength             10020 non-null  int64
#  30  Balance              10020 non-null  int64
#  31  Sprint Speed         10020 non-null  int64
#  32  Agility              10020 non-null  int64
#  33  Jumping              10020 non-null  int64
#  34  Heading              10020 non-null  int64
#  35  Shot Power           10020 non-null  int64
#  36  Finishing            10020 non-null  int64
#  37  Long Shots           10020 non-null  int64
#  38  Curve                10020 non-null  int64
#  39  FK Acc.              10020 non-null  int64
#  40  Penalties            10020 non-null  int64
#  41  Volleys              10020 non-null  int64
#  42  GK Positioning       10020 non-null  int64
#  43  GK Diving            10020 non-null  int64
#  44  GK Handling          10020 non-null  int64
#  45  GK Kicking           10020 non-null  int64
#  46  GK Reflexes          10020 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(38), object(6)
# memory usage: 3.6+ MB

# %% [markdown]
# After remove features which have large missing values, our dataframe still have missing values. So that, we need to fill these missing values so that they can be used in analysis.

# %%
raw_df['Value'] = raw_df['Value'].fillna(raw_df['Value'].fillna(method='ffill').fillna(method='bfill'))
raw_df['Wage'] = raw_df['Wage'].fillna(raw_df['Wage'].fillna(method='ffill').fillna(method='bfill'))
display(raw_df)
# Out:
#                     Name  Height  Weight Preferred Foot Birth Date  Age  \
# 0        Erling Haaland      195      94           Left 2000-07-21   23
# 1         Kylian Mbappé      182      75          Right 1998-12-20   24
# 2       Kevin De Bruyne      181      75          Right 1991-06-28   32
# 3            Harry Kane      188      85          Right 1993-07-28   30
# 4      Thibaut Courtois      199      96           Left 1992-05-11   31
# ...                  ...     ...     ...            ...        ...  ...
# 10015     Tim Schreiber      191      87          Right 2002-04-24   21
# 10016     Calvin Ramsay      177      68          Right 2003-07-31   20
# 10017     Tomás Salazar      170      60          Right 2000-06-06   23
# 10018     Arda Kızıldağ      187      77          Right 1998-10-15   25
# 10019     Cristian Cauz      188      78           Left 1996-08-15   27
#
#          Nation                      Club                      League  \
# 0        Norway           Manchester City  England Premier League (1)
# 1        France       Paris Saint-Germain          France Ligue 1 (1)
# 2       Belgium           Manchester City  England Premier League (1)
# 3       England            Bayern München   Germany 1. Bundesliga (1)
# 4       Belgium               Real Madrid  Spain Primera Division (1)
# ...         ...                       ...                         ...
# 10015   Germany         1. FC Saarbrücken         Germany 3. Liga (3)
# 10016  Scotland         Preston North End    England Championship (2)
# 10017  Colombia  Águilas Doradas Rionegro       CONMEBOL Sudamericana
# 10018    Turkey              Gaziantep FK        Turkey Super Lig (1)
# 10019     Italy                    Modena           Italy Serie B (2)
#
#       Preferred Positions  ...  Long Shots  Curve  FK Acc.  Penalties  \
# 0                      ST  ...          86     77       62         84
# 1                  ST, LW  ...          83     80       69         84
# 2                 CM, CAM  ...          92     92       83         83
# 3                      ST  ...          87     82       65         92
# 4                      GK  ...          17     19       20         27
# ...                   ...  ...         ...    ...      ...        ...
# 10015                  GK  ...           6     11       11         18
# 10016             RWB, RB  ...          43     61       54         42
# 10017                  CM  ...          64     49       60         55
# 10018                  CB  ...          31     28       33         53
# 10019              LB, CB  ...          46     60       48         54
#
#        Volleys  GK Positioning  GK Diving  GK Handling  GK Kicking  \
# 0           90              11          7           14          13
# 1           85              11         13            5           7
# 2           83              10         15           13           5
# 3           89              14          8           10          11
# 4           12              90         85           89          76
# ...        ...             ...        ...          ...         ...
# 10015        9              59         69           61          63
# 10016       27               9         13            8           9
# 10017       38               5          6           11           8
# 10018       29              13         10           13          14
# 10019       39               7         11           10          14
#
#        GK Reflexes
# 0                7
# 1                6
# 2               13
# 3               11
# 4               93
# ...            ...
# 10015           70
# 10016            8
# 10017           10
# 10018            9
# 10019            7
#
# [10020 rows x 47 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 47 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  int64
#  2   Weight               10020 non-null  int64
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  datetime64[ns]
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Club                 10020 non-null  object
#  8   League               10020 non-null  object
#  9   Preferred Positions  10020 non-null  object
#  10  OVR                  10020 non-null  int64
#  11  POT                  10020 non-null  int64
#  12  Value                10020 non-null  float64
#  13  Wage                 10020 non-null  float64
#  14  Ball Control         10020 non-null  int64
#  15  Dribbling            10020 non-null  int64
#  16  Slide Tackle         10020 non-null  int64
#  17  Stand Tackle         10020 non-null  int64
#  18  Aggression           10020 non-null  int64
#  19  Reactions            10020 non-null  int64
#  20  Att. Position        10020 non-null  int64
#  21  Interceptions        10020 non-null  int64
#  22  Vision               10020 non-null  int64
#  23  Composure            10020 non-null  int64
#  24  Crossing             10020 non-null  int64
#  25  Short Pass           10020 non-null  int64
#  26  Long Pass            10020 non-null  int64
#  27  Acceleration         10020 non-null  int64
#  28  Stamina              10020 non-null  int64
#  29  Strength             10020 non-null  int64
#  30  Balance              10020 non-null  int64
#  31  Sprint Speed         10020 non-null  int64
#  32  Agility              10020 non-null  int64
#  33  Jumping              10020 non-null  int64
#  34  Heading              10020 non-null  int64
#  35  Shot Power           10020 non-null  int64
#  36  Finishing            10020 non-null  int64
#  37  Long Shots           10020 non-null  int64
#  38  Curve                10020 non-null  int64
#  39  FK Acc.              10020 non-null  int64
#  40  Penalties            10020 non-null  int64
#  41  Volleys              10020 non-null  int64
#  42  GK Positioning       10020 non-null  int64
#  43  GK Diving            10020 non-null  int64
#  44  GK Handling          10020 non-null  int64
#  45  GK Kicking           10020 non-null  int64
#  46  GK Reflexes          10020 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(38), object(6)
# memory usage: 3.6+ MB

# %% [markdown]
# <h3>Group feature</h3>

# %% [markdown]
# `raw_df` have so many columnns, that make them distracted to analyze.
# To further streamline the dataset and improve analytical focus, consider merging related columns into cohesive groups, such as **'Ball Skills,' 'Defence,' 'Mental,' 'Passing,' 'Physical,' 'Shooting,' and 'Goalkeeper.'**
# This grouping approach enhances the organization of the data, making it more accessible and facilitating a more insightful analysis of player performance.

# %%
raw_df['Ball Skills']=(raw_df['Ball Control']+raw_df['Dribbling'])/2
raw_df['Defence']=(raw_df['Slide Tackle']+raw_df['Stand Tackle'])/2
raw_df['Mental'] = raw_df.loc[:,'Aggression':'Composure'].mean(axis=1)
raw_df['Passing'] = raw_df.loc[:,'Crossing':'Long Pass'].mean(axis=1)
raw_df['Physical'] = raw_df.loc[:,'Acceleration':'Jumping'].mean(axis=1)
raw_df['Shooting'] = raw_df.loc[:,'Heading':'Volleys'].mean(axis=1)
raw_df['Goalkeeper'] = raw_df.loc[:,'GK Positioning':'GK Reflexes'].mean(axis=1)
raw_df.drop(columns=raw_df.columns[14:47], inplace=True)

# %%
raw_df = round(raw_df, 1)
raw_df
# Out:
#                     Name  Height  Weight Preferred Foot Birth Date  Age  \
# 0        Erling Haaland      195      94           Left 2000-07-21   23
# 1         Kylian Mbappé      182      75          Right 1998-12-20   24
# 2       Kevin De Bruyne      181      75          Right 1991-06-28   32
# 3            Harry Kane      188      85          Right 1993-07-28   30
# 4      Thibaut Courtois      199      96           Left 1992-05-11   31
# ...                  ...     ...     ...            ...        ...  ...
# 10015     Tim Schreiber      191      87          Right 2002-04-24   21
# 10016     Calvin Ramsay      177      68          Right 2003-07-31   20
# 10017     Tomás Salazar      170      60          Right 2000-06-06   23
# 10018     Arda Kızıldağ      187      77          Right 1998-10-15   25
# 10019     Cristian Cauz      188      78           Left 1996-08-15   27
#
#          Nation                      Club                      League  \
# 0        Norway           Manchester City  England Premier League (1)
# 1        France       Paris Saint-Germain          France Ligue 1 (1)
# 2       Belgium           Manchester City  England Premier League (1)
# 3       England            Bayern München   Germany 1. Bundesliga (1)
# 4       Belgium               Real Madrid  Spain Primera Division (1)
# ...         ...                       ...                         ...
# 10015   Germany         1. FC Saarbrücken         Germany 3. Liga (3)
# 10016  Scotland         Preston North End    England Championship (2)
# 10017  Colombia  Águilas Doradas Rionegro       CONMEBOL Sudamericana
# 10018    Turkey              Gaziantep FK        Turkey Super Lig (1)
# 10019     Italy                    Modena           Italy Serie B (2)
#
#       Preferred Positions  ...  POT        Value      Wage  Ball Skills  \
# 0                      ST  ...   94  157000000.0  340000.0         80.5
# 1                  ST, LW  ...   94  153500000.0  225000.0         92.5
# 2                 CM, CAM  ...   91  103000000.0  350000.0         89.0
# 3                      ST  ...   90  119500000.0  170000.0         84.5
# 4                      GK  ...   90   63000000.0  250000.0         18.0
# ...                   ...  ...  ...          ...       ...          ...
# 10015                  GK  ...   75     625000.0    5200.0         16.5
# 10016             RWB, RB  ...   81     700000.0    9700.0         66.0
# 10017                  CM  ...   74     825000.0    3800.0         65.0
# 10018                  CB  ...   72     725000.0    3000.0         48.0
# 10019              LB, CB  ...   66     700000.0    1500.0         60.5
#
#        Defence  Mental  Passing  Physical  Shooting  Goalkeeper
# 0         38.0    80.2     59.0      83.7      84.0        10.4
# 1         33.0    76.7     78.3      89.0      82.2         8.4
# 2         61.5    84.0     94.3      75.7      83.1        11.2
# 3         42.0    81.3     85.0      75.9      86.5        10.8
# 4         17.0    41.5     27.3      54.0      22.4        86.6
# ...        ...     ...      ...       ...       ...         ...
# 10015     12.5    30.0     31.3      40.4      14.9        64.4
# 10016     58.0    58.7     60.7      70.7      47.0         9.4
# 10017     58.5    60.3     59.0      58.4      53.9         8.0
# 10018     67.5    55.2     52.0      63.1      40.8        11.8
# 10019     68.0    55.3     54.0      65.1      50.1         9.8
#
# [10020 rows x 21 columns]

# %% [markdown]
# <h3>What does each line mean? Does it matter if the lines have different meanings?</h3>

# %% [markdown]
# Each line in the provided data represents information about a specific player in a football (soccer) context.
#
# These lines provide a comprehensive overview of each player's characteristics and abilities. The differences in meanings among the lines are expected and reflect the diversity of player positions, attributes, and roles within a football team. The dataset captures a range of player types, from strikers (ST) and midfielders (CM, CAM) to goalkeepers (GK), each with their own set of skills and attributes.
#
# Analyzing this data allows for comparisons between players, understanding their strengths and weaknesses, and making informed decisions, such as scouting or selecting players for specific positions on a team.

# %% [markdown]
# <h3>Does the raw data have duplicate rows?</h3>

# %%
num_duplicated_rows = None
dupli=raw_df.duplicated()
count=0
for i in dupli:
    if i == True:
        count+=1
num_duplicated_rows=count

# %%
# TEST
if num_duplicated_rows == 0:
    print(f"Your raw data have no duplicated line.!")
else:
    if num_duplicated_rows > 1:
        ext = "lines"
    else:
        ext = "line"
    print(f"Your raw data have {num_duplicated_rows} duplicated " + ext + ". Please de-deduplicate your raw data.!")
# Out:
# Your raw data have no duplicated line.!

# %%
# De-deduplicate raw data
raw_df=raw_df.drop_duplicates()

# %% [markdown]
# ### Correlation between features in dataset

# %%
numeric_cols = []
for col in raw_df:
    if raw_df[col].dtype in ['int', 'float']:
        numeric_cols.append(col)
numeric_df = raw_df[numeric_cols]
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.show()

# %% [markdown]
# <h3>What does each column mean?</h3>

# %% [markdown]
# <div>
#
# **Name**: The player's name.
#
# **Height**: The player's height.
#
# **Weight**: The player's weight.
#
# **Preferred Foot**: The foot that the player prefers to use (Left or Right).
#
# **Birth Date**: The player's date of birth.
#
# **Age**: The player's current age.
#
# **Nation**: The player's citizenship.
#
# **Club**: Club the player is playing for.
#
# **League**: The tournament where football players are competing.
#
# **Preferred Positions**: The positions on the field that the player prefers to play.
#
# **OVR (Overall)**: The player's overall skill level or rating.
#
# **POT (Potential)**: The player's potential skill level or rating.
#
# **Value**: The estimated market value of the player.
#
# **Wage**: The player's weekly wage.
#
# **Ball Skills**: Composite score representing ball control and dribbling skills.
#
# **Defence**: Composite score representing defensive skills, combining slide tackle and stand tackle.
#
# **Mental**: The average of attributes related to mental skills (Aggression to Composure).
#
# **Passing**: The average of attributes related to passing skills (Crossing to Long Pass).
#
# **Physical**: The average of attributes related to physical skills (Acceleration to Jumping).
#
# **Shooting**: The average of attributes related to shooting skills (Heading to Volleys).
#
# **Goalkeeper**: The average of attributes related to goalkeeping skills.
# </div>

# %% [markdown]
# <h3>Save your processed data</h3>

# %%
raw_df.to_csv("../Data/data_footballer_processed.csv", index=False)
